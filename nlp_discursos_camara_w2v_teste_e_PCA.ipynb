# %% [markdown]
# <a href="https://colab.research.google.com/github/rmontenegroo/discursos/blob/main/nlp_discursos_camara_w2v_teste_e_PCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Módulos

# %%
# !pip install --upgrade gensim==4.1.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gensim==4.1.2
#   Downloading gensim-4.1.2-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (24.1 MB)
#      |████████████████████████████████| 24.1 MB 58.3 MB/s
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim==4.1.2) (1.4.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from gensim==4.1.2) (5.2.1)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.7/dist-packages (from gensim==4.1.2) (1.21.6)
# Installing collected packages: gensim
#   Attempting uninstall: gensim
#     Found existing installation: gensim 3.6.0
#     Uninstalling gensim-3.6.0:
#       Successfully uninstalled gensim-3.6.0
# Successfully installed gensim-4.1.2

# %%
import os
import gensim
import nltk
import re
import wordcloud

import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

nltk.download('punkt')

from gensim.models import Word2Vec
from sklearn.decomposition import PCA
from collections import Counter
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# # Parâmetros

# %%
ROOTDIR = '/content/drive/MyDrive/Pós/discursos/'

# %% [markdown]
# # Carregar modelo

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## vector 50

# %%
model50 = Word2Vec.load(ROOTDIR + 'data/camares.50.w2v')

# %% [markdown]
# ## vector 100

# %%
model100 = Word2Vec.load(ROOTDIR + 'data/camares.100.w2v')

# %% [markdown]
# ## vector 300

# %%
model300 = Word2Vec.load(ROOTDIR + 'data/camares.300.w2v')

# %% [markdown]
# ## Testes de similaridade

# %%
model50.wv.most_similar(['eleição',], topn=10)
# Out:
# [('candidatura', 0.7527958750724792),
#  ('chapa', 0.742612898349762),
#  ('reeleição', 0.7282460331916809),
#  ('diplomação', 0.7032694816589355),
#  ('legenda', 0.6879709362983704),
#  ('campanha', 0.6823124885559082),
#  ('coligação', 0.6714757084846497),
#  ('semifinal', 0.6598116755485535),
#  ('urna', 0.6527472138404846),
#  ('derrota', 0.6527199745178223)]

# %%
model100.wv.most_similar(['eleição',], topn=10)
# Out:
# [('chapa', 0.6150792241096497),
#  ('candidatura', 0.5966408848762512),
#  ('urna', 0.5538191199302673),
#  ('coligação', 0.5537552237510681),
#  ('reeleição', 0.5467877388000488),
#  ('legenda', 0.525554358959198),
#  ('diplomação', 0.5130453109741211),
#  ('expointer', 0.5056230425834656),
#  ('recaída', 0.4853443205356598),
#  ('legislatura', 0.4802771508693695)]

# %%
model300.wv.most_similar(['eleição',], topn=10)
# Out:
# [('eleições', 0.5298439860343933),
#  ('reeleição', 0.46465834975242615),
#  ('chapa', 0.44423139095306396),
#  ('reeleito', 0.4137851893901825),
#  ('candidato', 0.4078674912452698),
#  ('disputou', 0.40283364057540894),
#  ('coligação', 0.38714927434921265),
#  ('candidatura', 0.3836616575717926),
#  ('legenda', 0.38306790590286255),
#  ('eleito', 0.3782552182674408)]

# %% [markdown]
# ### Visualização com PCA

# %%
TAMANHO_MINIMO_PALAVRA = 4
QTD_PALAVRAS = 1000

counter = Counter([w for w in list(model50.wv.key_to_index) if len(w) >= TAMANHO_MINIMO_PALAVRA])

pca = PCA(n_components=3)

palavras_mais_freq = [w for w, f in counter.most_common(QTD_PALAVRAS)]

result = pca.fit_transform(model50.wv.vectors_for_all(keys=palavras_mais_freq).vectors)

fig = px.scatter_3d(
    result, x=0, y=1, z=2, 
    text=palavras_mais_freq
)

fig.show();
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="3727d5b2-f518-4894-b2af-49cc0f654e67" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3727d5b2-f518-4894-b2af-49cc0f654e67")) {                    Plotly.newPlot(                        "3727d5b2-f518-4894-b2af-49cc0f654e67",                        [{"hovertemplate":"0=%{x}<br>1=%{y}<br>2=%{z}<br>text=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers+text","name":"","scene":"scene","showlegend":false,"text":["para","presidente","mais","como","brasil","muito","isso","governo","pelo","est\u00e1","pela","deputado","pa\u00eds","deputados","tamb\u00e9m","estado","essa","todos","esse","casa","aqui","hoje","porque","nosso","federal","quero","anos","grande","esta","nacional","projeto","fazer","est\u00e3o","sobre","sras","povo","nossa","obrigado","ainda","este","sa\u00fade","temos","pessoas","seja","quando","trabalho","brasileiro","estamos","popula\u00e7\u00e3o","contra","momento","agora","pol\u00edtica","educa\u00e7\u00e3o","dizer","importante","neste","c\u00e2mara","forma","entre","quem","seus","todo","vida","foram","ent\u00e3o","brasileira","mesmo","vamos","p\u00fablica","pode","minha","recursos","nesta","portanto","desta","milh\u00f5es","sociedade","p\u00fablico","apenas","cidade","maior","comiss\u00e3o","sendo","reais","ministro","estados","tempo","social","cada","munic\u00edpios","programa","minist\u00e9rio","desenvolvimento","parlamentares","paulo","assim","trabalhadores","parte","brasileiros","mundo","outros","partido","medida","esses","poder","quest\u00e3o","suas","ser\u00e1","regi\u00e3o","todas","dessa","meio","seguran\u00e7a","al\u00e9m","direito","eles","lula","sess\u00e3o","justi\u00e7a","reforma","deste","toda","primeiro","desse","onde","situa\u00e7\u00e3o","pronunciamento","rela\u00e7\u00e3o","mat\u00e9ria","tenho","tudo","direitos","processo","congresso","mulheres","sempre","qual","essas","inclusive","respeito","ordem","emenda","segundo","sistema","pelos","rep\u00fablica","constitui\u00e7\u00e3o","exemplo","janeiro","outro","precisamos","plen\u00e1rio","podemos","qualquer","defesa","munic\u00edpio","acordo","economia","tribuna","pois","governador","alguns","empresas","especial","fato","\u00e1rea","deputada","voto","novo","menos","depois","caso","proposta","oportunidade","votar","vota\u00e7\u00e3o","vezes","precisa","dinheiro","dias","provis\u00f3ria","outras","setor","bilh\u00f5es","principalmente","apoio","trata","quanto","deve","muitos","falar","pol\u00edcia","desde","bolsonaro","verdade","nossos","quer","nesse","luta","semana","gostaria","melhor","fam\u00edlia","hist\u00f3ria","senado","condi\u00e7\u00f5es","import\u00e2ncia","problema","preciso","parlamentar","queremos","prefeito","viol\u00eancia","sentido","muitas","bancada","nada","texto","grandes","feito","aqueles","tinha","revis\u00e3o","ontem","disse","uni\u00e3o","dilma","p\u00fablicos","frente","renda","pa\u00edses","pe\u00e7o","tanto","pol\u00edticas","qualidade","nome","disso","mesa","crise","pouco","carlos","sido","estou","deixar","falta","produ\u00e7\u00e3o","certeza","a\u00e7\u00f5es","colegas","aten\u00e7\u00e3o","debate","fazendo","jos\u00e9","durante","conta","presid\u00eancia","estar","energia","medidas","l\u00edder","projetos","poss\u00edvel","favor","quase","geral","empresa","sociais","parlamento","n\u00famero","pessoa","servi\u00e7os","discurso","presidenta","nova","democracia","antes","responsabilidade","comunica\u00e7\u00e3o","nossas","partir","aumento","econ\u00f4mica","outra","fam\u00edlias","presen\u00e7a","p\u00fablicas","oradora","pauta","houve","tema","muita","norte","servidores","crime","valor","palavra","mulher","sejam","passado","registro","parab\u00e9ns","v\u00e1rios","crian\u00e7as","previ ...

# %%
TAMANHO_MINIMO_PALAVRA = 4
QTD_PALAVRAS = 1000

counter = Counter([w for w in list(model100.wv.key_to_index) if len(w) >= TAMANHO_MINIMO_PALAVRA])

pca = PCA(n_components=3)

palavras_mais_freq = [w for w, f in counter.most_common(QTD_PALAVRAS)]

result = pca.fit_transform(model100.wv.vectors_for_all(keys=palavras_mais_freq).vectors)

fig = px.scatter_3d(
    result, x=0, y=1, z=2, 
    text=palavras_mais_freq
)

fig.show();
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="9e439385-9fb9-4f57-9dc8-56b41a277a32" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9e439385-9fb9-4f57-9dc8-56b41a277a32")) {                    Plotly.newPlot(                        "9e439385-9fb9-4f57-9dc8-56b41a277a32",                        [{"hovertemplate":"0=%{x}<br>1=%{y}<br>2=%{z}<br>text=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers+text","name":"","scene":"scene","showlegend":false,"text":["para","presidente","mais","como","brasil","muito","isso","governo","pelo","est\u00e1","pela","deputado","pa\u00eds","deputados","tamb\u00e9m","estado","essa","todos","esse","casa","aqui","hoje","porque","nosso","federal","quero","anos","grande","esta","nacional","projeto","fazer","est\u00e3o","sobre","sras","povo","nossa","obrigado","ainda","este","sa\u00fade","temos","pessoas","seja","quando","trabalho","brasileiro","estamos","popula\u00e7\u00e3o","contra","momento","agora","pol\u00edtica","educa\u00e7\u00e3o","dizer","importante","neste","c\u00e2mara","forma","entre","quem","seus","todo","vida","foram","ent\u00e3o","brasileira","mesmo","vamos","p\u00fablica","pode","minha","recursos","nesta","portanto","desta","milh\u00f5es","sociedade","p\u00fablico","apenas","cidade","maior","comiss\u00e3o","sendo","reais","ministro","estados","tempo","social","cada","munic\u00edpios","programa","minist\u00e9rio","desenvolvimento","parlamentares","paulo","assim","trabalhadores","parte","brasileiros","mundo","outros","partido","medida","esses","poder","quest\u00e3o","suas","ser\u00e1","regi\u00e3o","todas","dessa","meio","seguran\u00e7a","al\u00e9m","direito","eles","lula","sess\u00e3o","justi\u00e7a","reforma","deste","toda","primeiro","desse","onde","situa\u00e7\u00e3o","pronunciamento","rela\u00e7\u00e3o","mat\u00e9ria","tenho","tudo","direitos","processo","congresso","mulheres","sempre","qual","essas","inclusive","respeito","ordem","emenda","segundo","sistema","pelos","rep\u00fablica","constitui\u00e7\u00e3o","exemplo","janeiro","outro","precisamos","plen\u00e1rio","podemos","qualquer","defesa","munic\u00edpio","acordo","economia","tribuna","pois","governador","alguns","empresas","especial","fato","\u00e1rea","deputada","voto","novo","menos","depois","caso","proposta","oportunidade","votar","vota\u00e7\u00e3o","vezes","precisa","dinheiro","dias","provis\u00f3ria","outras","setor","bilh\u00f5es","principalmente","apoio","trata","quanto","deve","muitos","falar","pol\u00edcia","desde","bolsonaro","verdade","nossos","quer","nesse","luta","semana","gostaria","melhor","fam\u00edlia","hist\u00f3ria","senado","condi\u00e7\u00f5es","import\u00e2ncia","problema","preciso","parlamentar","queremos","prefeito","viol\u00eancia","sentido","muitas","bancada","nada","texto","grandes","feito","aqueles","tinha","revis\u00e3o","ontem","disse","uni\u00e3o","dilma","p\u00fablicos","frente","renda","pa\u00edses","pe\u00e7o","tanto","pol\u00edticas","qualidade","nome","disso","mesa","crise","pouco","carlos","sido","estou","deixar","falta","produ\u00e7\u00e3o","certeza","a\u00e7\u00f5es","colegas","aten\u00e7\u00e3o","debate","fazendo","jos\u00e9","durante","conta","presid\u00eancia","estar","energia","medidas","l\u00edder","projetos","poss\u00edvel","favor","quase","geral","empresa","sociais","parlamento","n\u00famero","pessoa","servi\u00e7os","discurso","presidenta","nova","democracia","antes","responsabilidade","comunica\u00e7\u00e3o","nossas","partir","aumento","econ\u00f4mica","outra","fam\u00edlias","presen\u00e7a","p\u00fablicas","oradora","pauta","houve","tema","muita","norte","servidores","crime","valor","palavra","mulher","sejam","passado","registro","parab\u00e9ns","v\u00e1rios","crian\u00e7as","previ ...

# %%
TAMANHO_MINIMO_PALAVRA = 4
QTD_PALAVRAS = 1000

counter = Counter([w for w in list(model300.wv.key_to_index) if len(w) >= TAMANHO_MINIMO_PALAVRA])

pca = PCA(n_components=3)

palavras_mais_freq = [w for w, f in counter.most_common(QTD_PALAVRAS)]

result = pca.fit_transform(model300.wv.vectors_for_all(keys=palavras_mais_freq).vectors)

fig = px.scatter_3d(
    result, x=0, y=1, z=2, 
    text=palavras_mais_freq
)

fig.show();
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="03bc37af-94f5-400b-a0fa-5ad2fb026f7a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("03bc37af-94f5-400b-a0fa-5ad2fb026f7a")) {                    Plotly.newPlot(                        "03bc37af-94f5-400b-a0fa-5ad2fb026f7a",                        [{"hovertemplate":"0=%{x}<br>1=%{y}<br>2=%{z}<br>text=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers+text","name":"","scene":"scene","showlegend":false,"text":["para","presidente","mais","como","brasil","muito","isso","governo","pelo","est\u00e1","pela","deputado","pa\u00eds","deputados","tamb\u00e9m","estado","essa","todos","esse","casa","aqui","hoje","porque","nosso","federal","quero","anos","grande","esta","nacional","projeto","fazer","est\u00e3o","sobre","sras","povo","nossa","obrigado","ainda","este","sa\u00fade","temos","pessoas","seja","quando","trabalho","brasileiro","estamos","popula\u00e7\u00e3o","contra","momento","agora","pol\u00edtica","educa\u00e7\u00e3o","dizer","importante","neste","c\u00e2mara","forma","entre","quem","seus","todo","vida","foram","ent\u00e3o","brasileira","mesmo","vamos","p\u00fablica","pode","minha","recursos","nesta","portanto","desta","milh\u00f5es","sociedade","p\u00fablico","apenas","cidade","maior","comiss\u00e3o","sendo","reais","ministro","estados","tempo","social","cada","munic\u00edpios","programa","minist\u00e9rio","desenvolvimento","parlamentares","paulo","assim","trabalhadores","parte","brasileiros","mundo","outros","partido","medida","esses","poder","quest\u00e3o","suas","ser\u00e1","regi\u00e3o","todas","dessa","meio","seguran\u00e7a","al\u00e9m","direito","eles","lula","sess\u00e3o","justi\u00e7a","reforma","deste","toda","primeiro","desse","onde","situa\u00e7\u00e3o","pronunciamento","rela\u00e7\u00e3o","mat\u00e9ria","tenho","tudo","direitos","processo","congresso","mulheres","sempre","qual","essas","inclusive","respeito","ordem","emenda","segundo","sistema","pelos","rep\u00fablica","constitui\u00e7\u00e3o","exemplo","janeiro","outro","precisamos","plen\u00e1rio","podemos","qualquer","defesa","munic\u00edpio","acordo","economia","tribuna","pois","governador","alguns","empresas","especial","fato","\u00e1rea","deputada","voto","novo","menos","depois","caso","proposta","oportunidade","votar","vota\u00e7\u00e3o","vezes","precisa","dinheiro","dias","provis\u00f3ria","outras","setor","bilh\u00f5es","principalmente","apoio","trata","quanto","deve","muitos","falar","pol\u00edcia","desde","bolsonaro","verdade","nossos","quer","nesse","luta","semana","gostaria","melhor","fam\u00edlia","hist\u00f3ria","senado","condi\u00e7\u00f5es","import\u00e2ncia","problema","preciso","parlamentar","queremos","prefeito","viol\u00eancia","sentido","muitas","bancada","nada","texto","grandes","feito","aqueles","tinha","revis\u00e3o","ontem","disse","uni\u00e3o","dilma","p\u00fablicos","frente","renda","pa\u00edses","pe\u00e7o","tanto","pol\u00edticas","qualidade","nome","disso","mesa","crise","pouco","carlos","sido","estou","deixar","falta","produ\u00e7\u00e3o","certeza","a\u00e7\u00f5es","colegas","aten\u00e7\u00e3o","debate","fazendo","jos\u00e9","durante","conta","presid\u00eancia","estar","energia","medidas","l\u00edder","projetos","poss\u00edvel","favor","quase","geral","empresa","sociais","parlamento","n\u00famero","pessoa","servi\u00e7os","discurso","presidenta","nova","democracia","antes","responsabilidade","comunica\u00e7\u00e3o","nossas","partir","aumento","econ\u00f4mica","outra","fam\u00edlias","presen\u00e7a","p\u00fablicas","oradora","pauta","houve","tema","muita","norte","servidores","crime","valor","palavra","mulher","sejam","passado","registro","parab\u00e9ns","v\u00e1rios","crian\u00e7as","previ ...
